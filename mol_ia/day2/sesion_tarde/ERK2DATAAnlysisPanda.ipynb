# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Let´s create erk2 rotein inhibitors binary classification dataset for machine learning models.
#
# We´ll count ***value <= 10000 nM as "Active" or "positive (1) class. **
#
# And **value >=2000 nM as "Inactive" or "Negative (0)" class.**
#
# Bioactivity data -> data analysis-> create binary classification dataset("Active/Inactve")

# %%
x=pd.read_csv("erk2.csv",sep=";")

# %%
x
# Out:
#       Molecule ChEMBL ID Molecule Name  Molecule Max Phase Molecular Weight  \
# 0          CHEMBL1351580           NaN                   0           316.36
# 1          CHEMBL1493884           NaN                   0           210.30
# 2          CHEMBL1386667           NaN                   0           460.56
# 3          CHEMBL1455249           NaN                   0           230.31
# 4          CHEMBL1451172           NaN                   0           499.04
# ...                  ...           ...                 ...              ...
# 23225      CHEMBL4520788           NaN                   0           448.59
# 23226      CHEMBL2180604       TAK-593                   1           445.48
# 23227      CHEMBL4561806           NaN                   0           242.30
# 23228      CHEMBL3658647           NaN                   0           477.55
# 23229      CHEMBL3658846           NaN                   0           338.37
#
#       #RO5 Violations AlogP Compound Key  \
# ...

# %%
x["Standard Value"]
# Out:
# 0        25118.900
# 1        39810.700
# 2        31622.800
# 3        15848.900
# 4         7943.300
#            ...
# 23225     4570.000
# 23226    30000.000
# 23227       89.000
# 23228        1.348
# 23229      376.200
# Name: Standard Value, Length: 23230, dtype: float64

# %%
columns=pd.DataFrame(x.columns, columns=["column_name"])

# %%
columns
# Out:
#                    column_name
# 0           Molecule ChEMBL ID
# 1                Molecule Name
# 2           Molecule Max Phase
# 3             Molecular Weight
# 4              #RO5 Violations
# 5                        AlogP
# 6                 Compound Key
# 7                       Smiles
# 8                Standard Type
# 9            Standard Relation
# 10              Standard Value
# 11              Standard Units
# 12               pChEMBL Value
# 13       Data Validity Comment
# 14                     Comment
# 15                    Uo Units
# 16       Ligand Efficiency BEI
# 17        Ligand Efficiency LE
# 18       Ligand Efficiency LLE
# 19       Ligand Efficiency SEI
# 20         Potential Duplicate
# 21             Assay ChEMBL ID
# 22           Assay Description
# 23                  Assay Type
# 24               BAO Format ID
# 25                   BAO Label
# 26              Assay Organism
# 27      Assay Tissue ChEMBL ID
# 28           Assay Tissue Name
# ...

# %%
x1=x[["Molecule ChEMBL ID","Standard Value","Smiles","Standard Type","Standard Relation","Standard Units"]]

# %%
x1
# Out:
#       Molecule ChEMBL ID  Standard Value  \
# 0          CHEMBL1351580       25118.900
# 1          CHEMBL1493884       39810.700
# 2          CHEMBL1386667       31622.800
# 3          CHEMBL1455249       15848.900
# 4          CHEMBL1451172        7943.300
# ...                  ...             ...
# 23225      CHEMBL4520788        4570.000
# 23226      CHEMBL2180604       30000.000
# 23227      CHEMBL4561806          89.000
# 23228      CHEMBL3658647           1.348
# 23229      CHEMBL3658846         376.200
#
#                                                   Smiles Standard Type  \
# 0                    COc1cccc(CSc2nnc(-c3ccc(F)cc3)o2)c1       Potency
# 1                                NC(=O)c1c(N)sc2c1CCCCC2       Potency
# 2      COc1ccc(N2CCN(CCCNS(=O)(=O)c3ccc4c(c3)oc(=O)n4...       Potency
# 3                           CCCCc1nc2[nH]nc(N)c2c2c1CCC2       Potency
# 4      O=C(C1CCN(S(=O)(=O)c2cccc3cccnc23)CC1)N1CCN(c2...       Potency
# ...

# %%
x1["Standard Type"].value_counts()
# Out:
# Potency                                 13926
# IC50                                     4677
# Ki                                       1767
# Inhibition                               1549
# Activity                                  391
# Residual Activity                         316
# Kd apparent                               243
# Kd                                        206
# % Control                                  95
# Ka                                         10
# T1/2                                       10
# Kdiss                                      10
# Residual activity                           9
# FC                                          4
# % Ctrl                                      3
# NT                                          3
# Residual_activity                           3
# EC50                                        2
# Control                                     2
# Inihibition                                 1
# ...

# %%
x2=x1[x1["Standard Units"].str.contains("nM", na=False)] #None missing data

# %%
x2
# Out:
#       Molecule ChEMBL ID  Standard Value  \
# 0          CHEMBL1351580       25118.900
# 1          CHEMBL1493884       39810.700
# 2          CHEMBL1386667       31622.800
# 3          CHEMBL1455249       15848.900
# 4          CHEMBL1451172        7943.300
# ...                  ...             ...
# 23224      CHEMBL4538174          91.000
# 23225      CHEMBL4520788        4570.000
# 23226      CHEMBL2180604       30000.000
# 23228      CHEMBL3658647           1.348
# 23229      CHEMBL3658846         376.200
#
#                                                   Smiles Standard Type  \
# 0                    COc1cccc(CSc2nnc(-c3ccc(F)cc3)o2)c1       Potency
# 1                                NC(=O)c1c(N)sc2c1CCCCC2       Potency
# 2      COc1ccc(N2CCN(CCCNS(=O)(=O)c3ccc4c(c3)oc(=O)n4...       Potency
# 3                           CCCCc1nc2[nH]nc(N)c2c2c1CCC2       Potency
# 4      O=C(C1CCN(S(=O)(=O)c2cccc3cccnc23)CC1)N1CCN(c2...       Potency
# ...

# %%
x2=x2.sort_values("Standard Value", ascending=True)

# %%
x2
# Out:
#       Molecule ChEMBL ID  Standard Value  \
# 22948      CHEMBL4115001    4.310000e-03
# 57         CHEMBL4111166    5.000000e-03
# 22482      CHEMBL3904235    5.500000e-03
# 20268      CHEMBL3980387    6.120000e-03
# 2071       CHEMBL4107592    6.650000e-03
# ...                  ...             ...
# 14970      CHEMBL4128535    1.000000e+06
# 16699      CHEMBL4129626    1.000000e+06
# 15763      CHEMBL4128128    1.000000e+06
# 894        CHEMBL2297162    1.000000e+06
# 10678      CHEMBL1350100    5.011872e+06
#
#                                                   Smiles Standard Type  \
# 22948  Nc1ncc([C@@H]2CC[C@@H](O)[C@H](O)C2)nc1-c1ccc(...          IC50
# 57     NC[C@@H](NC(=O)c1ccc(-c2nc([C@@H]3CC[C@@H](O)[...          IC50
# 22482  Nc1ncc([C@H]2CC[C@H](O)[C@@H](O)C2)nc1-c1ccc(C...          IC50
# 20268  NC[C@@H](NC(=O)c1ccc(-c2nc(C3CCOCC3)cnc2N)cc1F...          IC50
# 2071   CNC[C@@H](NC(=O)c1ccc(-c2nc([C@H]3CC[C@H](O)CC...          IC50
# ...

# %%
x2.head()
# Out:
#       Molecule ChEMBL ID  Standard Value  \
# 22948      CHEMBL4115001         0.00431
# 57         CHEMBL4111166         0.00500
# 22482      CHEMBL3904235         0.00550
# 20268      CHEMBL3980387         0.00612
# 2071       CHEMBL4107592         0.00665
#
#                                                   Smiles Standard Type  \
# 22948  Nc1ncc([C@@H]2CC[C@@H](O)[C@H](O)C2)nc1-c1ccc(...          IC50
# 57     NC[C@@H](NC(=O)c1ccc(-c2nc([C@@H]3CC[C@@H](O)[...          IC50
# 22482  Nc1ncc([C@H]2CC[C@H](O)[C@@H](O)C2)nc1-c1ccc(C...          IC50
# 20268  NC[C@@H](NC(=O)c1ccc(-c2nc(C3CCOCC3)cnc2N)cc1F...          IC50
# 2071   CNC[C@@H](NC(=O)c1ccc(-c2nc([C@H]3CC[C@H](O)CC...          IC50
#
#       Standard Relation Standard Units
# 22948               '='             nM
# 57                  '='             nM
# 22482               '='             nM
# 20268               '='             nM
# 2071                '='             nM

# %%
x2.tail()
# Out:
#       Molecule ChEMBL ID  Standard Value  \
# 19198      CHEMBL4129032       1000000.0
# 12442      CHEMBL2297161       1000000.0
# 19020      CHEMBL4126333       1000000.0
# 20022      CHEMBL4127417       1000000.0
# 10678      CHEMBL1350100       5011872.3
#
#                                                   Smiles Standard Type  \
# 19198                         O=C1c2ccc(F)cc2CN1C1CCNCC1            Kd
# 12442  Cc1nc[nH]c1[C@@H]1c2nc[nH]c2CCN1Cc1nc2ccccc2[nH]1            Ki
# 19020                    O=C(O)c1ccc2nc(-c3ccccc3F)nn2c1            Kd
# 20022                        Fc1ccc2[nH]cc(C3CCCNC3)c2c1            Kd
# 10678        CCC(=O)Nc1cc(C(=O)NCC2CCCN2CC)c(OC)cc1N(C)C       Potency
#
#       Standard Relation Standard Units
# 19198               '>'             nM
# 12442               '='             nM
# 19020               '>'             nM
# 20022               '>'             nM
# 10678               '='             nM

# %%
x2["Molecule ChEMBL ID"].value_counts()
# Out:
# CHEMBL388978     12
# CHEMBL3590107    12
# CHEMBL4538174    10
# CHEMBL3544964    10
# CHEMBL3590106     9
#                  ..
# CHEMBL2004771     1
# CHEMBL2000894     1
# CHEMBL2003768     1
# CHEMBL1993243     1
# CHEMBL1350100     1
# Name: Molecule ChEMBL ID, Length: 17815, dtype: int64

# %%
CHEML388978=x2[x2["Molecule ChEMBL ID"].str.contains("CHEMBL388978")]

# %%
CHEML388978
# Out:
#       Molecule ChEMBL ID  Standard Value  \
# 21341       CHEMBL388978             1.0
# 17863       CHEMBL388978             2.5
# 7769        CHEMBL388978           370.0
# 6827        CHEMBL388978           370.0
# 21376       CHEMBL388978           659.1
# 12956       CHEMBL388978          1380.0
# 11784       CHEMBL388978          3948.0
# 6820        CHEMBL388978          4491.0
# 17518       CHEMBL388978          7300.0
# 1689        CHEMBL388978          7300.0
# 21951       CHEMBL388978          8451.0
# 19185       CHEMBL388978         34000.0
#
#                                                   Smiles Standard Type  \
# 21341  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50
# 17863  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50
# 7769   CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50
# 6827   CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50
# ...

# %% [markdown]
# Bioactivity data -> data analysis_> create binary classification dataset("Active", "Inactive")

# %%
active=x2[x2["Standard Value"]<=1000]
inactive=x2[x2["Standard Value"]>20000]

# %%
d1=active[active["Molecule ChEMBL ID"].str.contains("CHEMBL388978")]

# %%
d1
# Out:
#       Molecule ChEMBL ID  Standard Value  \
# 21341       CHEMBL388978             1.0
# 17863       CHEMBL388978             2.5
# 7769        CHEMBL388978           370.0
# 6827        CHEMBL388978           370.0
# 21376       CHEMBL388978           659.1
#
#                                                   Smiles Standard Type  \
# 21341  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50
# 17863  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50
# 7769   CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50
# 6827   CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50
# 21376  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50
#
#       Standard Relation Standard Units
# 21341               '<'             nM
# 17863               '='             nM
# 7769                '='             nM
# 6827                '='             nM
# 21376               '='             nM

# %%
d2=inactive[inactive["Molecule ChEMBL ID"].str.contains("CHEMBL388978")]

# %%
d2
# Out:
#       Molecule ChEMBL ID  Standard Value  \
# 19185       CHEMBL388978         34000.0
#
#                                                   Smiles Standard Type  \
# 19185  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50
#
#       Standard Relation Standard Units
# 19185               '='             nM

# %%
x2.drop_duplicates("Molecule ChEMBL ID", inplace=True)

# %%
x2=x2.reset_index(drop=True)

# %%
x2=pd.DataFrame(x2)

# %%
x2
# Out:
#       Molecule ChEMBL ID  Standard Value  \
# 0          CHEMBL4115001    4.310000e-03
# 1          CHEMBL4111166    5.000000e-03
# 2          CHEMBL3904235    5.500000e-03
# 3          CHEMBL3980387    6.120000e-03
# 4          CHEMBL4107592    6.650000e-03
# ...                  ...             ...
# 17810      CHEMBL4128535    1.000000e+06
# 17811      CHEMBL4129626    1.000000e+06
# 17812      CHEMBL4128128    1.000000e+06
# 17813      CHEMBL2297162    1.000000e+06
# 17814      CHEMBL1350100    5.011872e+06
#
#                                                   Smiles Standard Type  \
# 0      Nc1ncc([C@@H]2CC[C@@H](O)[C@H](O)C2)nc1-c1ccc(...          IC50
# 1      NC[C@@H](NC(=O)c1ccc(-c2nc([C@@H]3CC[C@@H](O)[...          IC50
# 2      Nc1ncc([C@H]2CC[C@H](O)[C@@H](O)C2)nc1-c1ccc(C...          IC50
# 3      NC[C@@H](NC(=O)c1ccc(-c2nc(C3CCOCC3)cnc2N)cc1F...          IC50
# 4      CNC[C@@H](NC(=O)c1ccc(-c2nc([C@H]3CC[C@H](O)CC...          IC50
# ...

# %%
columns
# Out:
#                    column_name
# 0           Molecule ChEMBL ID
# 1                Molecule Name
# 2           Molecule Max Phase
# 3             Molecular Weight
# 4              #RO5 Violations
# 5                        AlogP
# 6                 Compound Key
# 7                       Smiles
# 8                Standard Type
# 9            Standard Relation
# 10              Standard Value
# 11              Standard Units
# 12               pChEMBL Value
# 13       Data Validity Comment
# 14                     Comment
# 15                    Uo Units
# 16       Ligand Efficiency BEI
# 17        Ligand Efficiency LE
# 18       Ligand Efficiency LLE
# 19       Ligand Efficiency SEI
# 20         Potential Duplicate
# 21             Assay ChEMBL ID
# 22           Assay Description
# 23                  Assay Type
# 24               BAO Format ID
# 25                   BAO Label
# 26              Assay Organism
# 27      Assay Tissue ChEMBL ID
# 28           Assay Tissue Name
# ...

# %%
columns.to.csv("erk2_columns.csv",sep=")
# Out:
#   File "C:\Users\L03121~1\AppData\Local\Temp/ipykernel_22444/2029187873.py", line 1
#     columns.to.csv("erk2_columns.csv",sep=")
#                                             ^
# SyntaxError: EOL while scanning string literal

# %%
x.head()
# Out:
#   Molecule ChEMBL ID Molecule Name  Molecule Max Phase Molecular Weight  \
# 0      CHEMBL1351580           NaN                   0           316.36
# 1      CHEMBL1493884           NaN                   0           210.30
# 2      CHEMBL1386667           NaN                   0           460.56
# 3      CHEMBL1455249           NaN                   0           230.31
# 4      CHEMBL1451172           NaN                   0           499.04
#
#   #RO5 Violations AlogP Compound Key  \
# 0               0  4.18    SID850528
# 1               0  1.70   SID3712084
# 2               0  1.63   SID7966145
# 3               0  2.37    SID859084
# 4               0  3.64   SID7967243
#
#                                               Smiles Standard Type  \
# 0                COc1cccc(CSc2nnc(-c3ccc(F)cc3)o2)c1       Potency
# 1                            NC(=O)c1c(N)sc2c1CCCCC2       Potency
# 2  COc1ccc(N2CCN(CCCNS(=O)(=O)c3ccc4c(c3)oc(=O)n4...       Potency
# ...

# %%
x2["Molecule ChEMBL ID"].value_counts()
# Out:
# CHEMBL4115001    1
# CHEMBL1447777    1
# CHEMBL1440725    1
# CHEMBL1426223    1
# CHEMBL1582279    1
#                 ..
# CHEMBL2004716    1
# CHEMBL1562756    1
# CHEMBL336961     1
# CHEMBL1982660    1
# CHEMBL1350100    1
# Name: Molecule ChEMBL ID, Length: 17815, dtype: int64

# %%
CHEML388978
# Out:
#       Molecule ChEMBL ID  Standard Value  \
# 21341       CHEMBL388978             1.0
# 17863       CHEMBL388978             2.5
# 7769        CHEMBL388978           370.0
# 6827        CHEMBL388978           370.0
# 21376       CHEMBL388978           659.1
# 12956       CHEMBL388978          1380.0
# 11784       CHEMBL388978          3948.0
# 6820        CHEMBL388978          4491.0
# 17518       CHEMBL388978          7300.0
# 1689        CHEMBL388978          7300.0
# 21951       CHEMBL388978          8451.0
# 19185       CHEMBL388978         34000.0
#
#                                                   Smiles Standard Type  \
# 21341  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50
# 17863  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50
# 7769   CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50
# 6827   CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50
# ...

# %%
CHEML388978["Standard Value"].mean()
# Out:
# 5689.383333333334

# %%
CHEML388978["new value"]=CHEML388978["Standard Value"].mean()
# Out:
# C:\Users\L03121898\AppData\Local\Schrodinger\PyMOL2\envs\Cadi22\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
CHEML388978
# Out:
#       Molecule ChEMBL ID  Standard Value  \
# 21341       CHEMBL388978             1.0
# 17863       CHEMBL388978             2.5
# 7769        CHEMBL388978           370.0
# 6827        CHEMBL388978           370.0
# 21376       CHEMBL388978           659.1
# 12956       CHEMBL388978          1380.0
# 11784       CHEMBL388978          3948.0
# 6820        CHEMBL388978          4491.0
# 17518       CHEMBL388978          7300.0
# 1689        CHEMBL388978          7300.0
# 21951       CHEMBL388978          8451.0
# 19185       CHEMBL388978         34000.0
#
#                                                   Smiles Standard Type  \
# 21341  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50
# 17863  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50
# 7769   CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50
# 6827   CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...          IC50
# ...
